# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sys
import random
from pprint import pprint

# %%
covid = pd.read_csv('03 - owid-covid-data (1).csv')

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93331 entries, 0 to 93330
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93331 non-null  object
#  1   continent                              88910 non-null  object
#  2   location                               93331 non-null  object
#  3   date                                   93331 non-null  object
#  4   total_cases                            90358 non-null  float64
#  5   new_cases                              90356 non-null  float64
#  6   new_cases_smoothed                     89344 non-null  float64
#  7   total_deaths                           80419 non-null  float64
#  8   new_deaths                             80576 non-null  float64
#  9   new_deaths_smoothed                    89344 non-null  float64
# ...

# %%
covid = covid[covid["location"] == "India"]

# %%
covid.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 38584      IND      Asia    India  2020-01-30          1.0        1.0
# 38585      IND      Asia    India  2020-01-31          1.0        0.0
# 38586      IND      Asia    India  2020-02-01          1.0        0.0
# 38587      IND      Asia    India  2020-02-02          2.0        1.0
# 38588      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 38584                 NaN           NaN         NaN                  NaN  ...
# 38585                 NaN           NaN         NaN                  NaN  ...
# 38586                 NaN           NaN         NaN                  NaN  ...
# 38587                 NaN           NaN         NaN                  NaN  ...
# 38588                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 38584 to 39074
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               491 non-null    object
#  1   continent                              491 non-null    object
#  2   location                               491 non-null    object
#  3   date                                   491 non-null    object
#  4   total_cases                            491 non-null    float64
#  5   new_cases                              491 non-null    float64
#  6   new_cases_smoothed                     486 non-null    float64
#  7   total_deaths                           450 non-null    float64
#  8   new_deaths                             450 non-null    float64
#  9   new_deaths_smoothed                    486 non-null    float64
# ...

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
covid = covid.drop(columns=['iso_code', 'continent', 'location','icu_patients',
       'icu_patients_per_million', 'hosp_patients',
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million','total_vaccinations',
       'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
       'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
       'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
       'new_vaccinations_smoothed_per_million'])

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 38584 to 39074
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             491 non-null    object
#  1   total_cases                      491 non-null    float64
#  2   new_cases                        491 non-null    float64
#  3   new_cases_smoothed               486 non-null    float64
#  4   total_deaths                     450 non-null    float64
#  5   new_deaths                       450 non-null    float64
#  6   new_deaths_smoothed              486 non-null    float64
#  7   total_cases_per_million          491 non-null    float64
#  8   new_cases_per_million            491 non-null    float64
#  9   new_cases_smoothed_per_million   486 non-null    float64
#  10  total_deaths_per_million         450 non-null    float64
# ...

# %%
covid.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000   0.707148            0.735100
# new_cases                           0.707148   1.000000            0.990252
# new_cases_smoothed                  0.735100   0.990252            1.000000
# total_deaths                        0.986775   0.609961            0.639159
# new_deaths                          0.711621   0.909445            0.946869
# new_deaths_smoothed                 0.735508   0.874777            0.923368
# total_cases_per_million             1.000000   0.707148            0.735100
# new_cases_per_million               0.707148   1.000000            0.990252
# new_cases_smoothed_per_million      0.735100   0.990252            1.000000
# total_deaths_per_million            0.986775   0.609961            0.639159
# new_deaths_per_million              0.711609   0.909445            0.946869
# ...

# %%
covid = covid.drop(columns = ['total_cases_per_million', 'new_cases_per_million', 'new_deaths_smoothed', 'new_cases_smoothed_per_million'])

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 38584 to 39074
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             491 non-null    object
#  1   total_cases                      491 non-null    float64
#  2   new_cases                        491 non-null    float64
#  3   new_cases_smoothed               486 non-null    float64
#  4   total_deaths                     450 non-null    float64
#  5   new_deaths                       450 non-null    float64
#  6   total_deaths_per_million         450 non-null    float64
#  7   new_deaths_per_million           450 non-null    float64
#  8   new_deaths_smoothed_per_million  486 non-null    float64
#  9   reproduction_rate                445 non-null    float64
#  10  new_tests                        422 non-null    float64
# ...

# %%
covid.columns
# Out:
# Index(['date', 'total_cases', 'new_cases', 'new_cases_smoothed',
#        'total_deaths', 'new_deaths', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_deaths_smoothed_per_million',
#        'reproduction_rate', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
covid_temp = covid.drop(columns = ['population', 'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index'])

# %%
covid_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 38584 to 39074
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             491 non-null    object
#  1   total_cases                      491 non-null    float64
#  2   new_cases                        491 non-null    float64
#  3   new_cases_smoothed               486 non-null    float64
#  4   total_deaths                     450 non-null    float64
#  5   new_deaths                       450 non-null    float64
#  6   total_deaths_per_million         450 non-null    float64
#  7   new_deaths_per_million           450 non-null    float64
#  8   new_deaths_smoothed_per_million  486 non-null    float64
#  9   reproduction_rate                445 non-null    float64
#  10  new_tests                        422 non-null    float64
# ...

# %%
covid_temp.head()
# Out:
#              date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 38584  2020-01-30          1.0        1.0                 NaN           NaN
# 38585  2020-01-31          1.0        0.0                 NaN           NaN
# 38586  2020-02-01          1.0        0.0                 NaN           NaN
# 38587  2020-02-02          2.0        1.0                 NaN           NaN
# 38588  2020-02-03          3.0        1.0                 NaN           NaN
#
#        new_deaths  total_deaths_per_million  new_deaths_per_million  \
# 38584         NaN                       NaN                     NaN
# 38585         NaN                       NaN                     NaN
# 38586         NaN                       NaN                     NaN
# 38587         NaN                       NaN                     NaN
# 38588         NaN                       NaN                     NaN
#
#        new_deaths_smoothed_per_million  reproduction_rate  new_tests  \
# ...

# %%
covid_temp.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000   0.707148            0.735100
# new_cases                           0.707148   1.000000            0.990252
# new_cases_smoothed                  0.735100   0.990252            1.000000
# total_deaths                        0.986775   0.609961            0.639159
# new_deaths                          0.711621   0.909445            0.946869
# total_deaths_per_million            0.986775   0.609961            0.639159
# new_deaths_per_million              0.711609   0.909445            0.946869
# new_deaths_smoothed_per_million     0.735517   0.874787            0.923377
# reproduction_rate                  -0.467276  -0.161131           -0.208717
# new_tests                           0.873402   0.719849            0.737076
# total_tests                         0.961575   0.596091            0.605172
# ...

# %%
covid_temp = covid_temp.drop(columns = ['total_deaths_per_million', 'new_tests_smoothed_per_thousand'])

# %%
covid_temp.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000   0.707148            0.735100
# new_cases                           0.707148   1.000000            0.990252
# new_cases_smoothed                  0.735100   0.990252            1.000000
# total_deaths                        0.986775   0.609961            0.639159
# new_deaths                          0.711621   0.909445            0.946869
# new_deaths_per_million              0.711609   0.909445            0.946869
# new_deaths_smoothed_per_million     0.735517   0.874787            0.923377
# reproduction_rate                  -0.467276  -0.161131           -0.208717
# new_tests                           0.873402   0.719849            0.737076
# total_tests                         0.961575   0.596091            0.605172
# total_tests_per_thousand            0.961575   0.596091            0.605171
# ...

# %%
covid_temp.columns
# Out:
# Index(['date', 'total_cases', 'new_cases', 'new_cases_smoothed',
#        'total_deaths', 'new_deaths', 'new_deaths_smoothed_per_million',
#        'reproduction_rate', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'stringency_index'],
#       dtype='object')

# %%
covid_temp = covid_temp.drop(columns = ['new_tests_smoothed', 'new_tests_per_thousand', 'total_tests_per_thousand', 'new_deaths_per_million'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19676\1607776854.py in <module>
# ----> 1 covid_temp = covid_temp.drop(columns = ['new_tests_smoothed', 'new_tests_per_thousand', 'total_tests_per_thousand', 'new_deaths_per_million'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
covid_temp.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000   0.707148            0.735100
# new_cases                           0.707148   1.000000            0.990252
# new_cases_smoothed                  0.735100   0.990252            1.000000
# total_deaths                        0.986775   0.609961            0.639159
# new_deaths                          0.711621   0.909445            0.946869
# new_deaths_smoothed_per_million     0.735517   0.874787            0.923377
# reproduction_rate                  -0.467276  -0.161131           -0.208717
# new_tests                           0.873402   0.719849            0.737076
# total_tests                         0.961575   0.596091            0.605172
# positive_rate                       0.337953   0.872484            0.863270
# tests_per_case                      0.071090  -0.496783           -0.489548
# ...

# %%
covid_temp.drop(columns = ['reproduction_rate', 'stringency_index', 'tests_per_case'])
# Out:
#              date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 38584  2020-01-30          1.0        1.0                 NaN           NaN
# 38585  2020-01-31          1.0        0.0                 NaN           NaN
# 38586  2020-02-01          1.0        0.0                 NaN           NaN
# 38587  2020-02-02          2.0        1.0                 NaN           NaN
# 38588  2020-02-03          3.0        1.0                 NaN           NaN
# ...           ...          ...        ...                 ...           ...
# 39070  2021-05-30   28047534.0   152734.0          185012.429      329100.0
# 39071  2021-05-31   28175044.0   127510.0          175167.143      331895.0
# 39072  2021-06-01   28307832.0   132788.0          164291.000      335102.0
# 39073  2021-06-02   28441986.0   134154.0          153270.429      337989.0
# 39074  2021-06-03   28574350.0   132364.0          145556.143      340702.0
#
# ...

# %%
covid_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 38584 to 39074
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date                             491 non-null    object
#  1   total_cases                      491 non-null    float64
#  2   new_cases                        491 non-null    float64
#  3   new_cases_smoothed               486 non-null    float64
#  4   total_deaths                     450 non-null    float64
#  5   new_deaths                       450 non-null    float64
#  6   new_deaths_smoothed_per_million  486 non-null    float64
#  7   reproduction_rate                445 non-null    float64
#  8   new_tests                        422 non-null    float64
#  9   total_tests                      432 non-null    float64
#  10  positive_rate                    441 non-null    float64
# ...
